# %% [markdown]
# # Data Models for gridded data
#
# differences between tabular and gridded data

# %%
import pathlib

# %%
import matplotlib

# %%
import iris
import iris.quickplot

# %% [markdown]
# ## Iris Python Library
# introduce cubes
#
# introduce netcdf files

# %% [markdown]
# ## Weater and climate Datasets

# %% [markdown]
# ### Weather dataset: UKV

# %%
ukv_root_dir  = pathlib.Path('/data','impactLab_event','intro_python_ds', 'ukv_daily')

# %%
var_dirs = {d1.stem: d1 for d1 in ukv_root_dir.iterdir()}

# %%
list(var_dirs.keys())
# Out:
# ['pmsl_mean',
#  'rain_mean',
#  't1o5m_max',
#  't1o5m_mean',
#  't1o5m_min',
#  'windgust_max',
#  'windspeed_mean']

# %%
current_var = 't1o5m_max'

# %%
ukv_temp_max = iris.load_cube([str(p1) for p1 in var_dirs[current_var].iterdir()])

# %%
ukv_temp_max
# Out:
# <iris 'Cube' of air_temperature / (K) (time: 30; grid_latitude: 808; grid_longitude: 621)>

# %%
# Out:
# <function matplotlib.pyplot.sca(ax)>

# %%
iris.quickplot.contourf(ukv_temp_max[0])
matplotlib.pyplot.gca().coastlines()
matplotlib.pyplot.gcf().set_size_inches(12,12)

# %% [markdown]
# ### Climate Dataset UKCP

# %%
ukcp_root_dir  = pathlib.Path('/data','impactLab_event','intro_python_ds', 'ukcp_rcp85')

# %%
ukcp_var_dirs = {d1.stem: d1 for d1 in ukcp_root_dir.iterdir()}

# %%
list(ukcp_var_dirs.keys())
# Out:
# ['pr', 'psl', 'sfcWind', 'tasmax', 'tasmin']

# %%
current_ukcp_var = 'pr'

# %%
ukcp_pr = iris.load_cube([str(p1) for p1 in ukcp_var_dirs[current_ukcp_var].iterdir()])

# %%
ukcp_pr
# Out:
# <iris 'Cube' of lwe_precipitation_rate / (mm/day) (ensemble_member: 1; time: 360; grid_latitude: 606; grid_longitude: 484)>

# %%
iris.quickplot.contourf(ukcp_pr[0,5,:,:])
matplotlib.pyplot.gca().coastlines()
matplotlib.pyplot.gcf().set_size_inches(12,12)

# %%
iris.quickplot.contourf(ukcp_pr.collapsed('time',iris.analysis.SUM).collapsed('ensemble_member', iris.analysis.SUM))
matplotlib.pyplot.gca().coastlines()
matplotlib.pyplot.gcf().set_size_inches(12,12)
# Out:
# C:\Users\stephen\.conda\envs\intro_python_ds_tutorial\lib\site-packages\iris\coords.py:1410: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'month_number'.
#   warnings.warn(msg.format(self.name()))
# C:\Users\stephen\.conda\envs\intro_python_ds_tutorial\lib\site-packages\iris\coords.py:1410: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'year'.
#   warnings.warn(msg.format(self.name()))
# C:\Users\stephen\.conda\envs\intro_python_ds_tutorial\lib\site-packages\iris\coords.py:1410: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'ensemble_member'.
#   warnings.warn(msg.format(self.name()))

# %% [markdown]
# ## Common operations on gridded data
# compare manual (numpy) vs iris
#
# get operations from Iris user guide
#
# https://scitools.org.uk/iris/docs/latest/userguide/index.html
#
# https://scitools.org.uk/iris/docs/latest/gallery.html

# %%
#loading data

# %%
# accessing data

# %%
# subsetting data - constraints by time

# %%
# subsetting - constaints by latitude/longitude

# %%
# operations on whole cubes

# %%
# reductions on cubes - mean across times

# %%
# reductions on cubes - mean across areas

# %%
# new operation - interpolation and regridding

# %% [markdown]
# ## Other libraries for gridded data - xarray
